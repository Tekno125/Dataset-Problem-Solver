# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook contains exploratory analysis of the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the raw data
df = pd.read_csv('../raw/dummy_data.csv')
df.head()

# %%
# Basic statistics
df.describe()
